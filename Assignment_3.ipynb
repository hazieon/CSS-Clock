# %% [markdown]
# <a href="https://colab.research.google.com/github/hazieon/CSS-Clock/blob/master/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hazel Andrew - Natural Language Processing Assignment 3
#
# ##  Identifying Subjectivity in Text
#
# - First, let's import and load all the necessary modules and datasets

# %%
import nltk
from nltk.corpus import subjectivity
from nltk.classify import NaiveBayesClassifier
from nltk.classify.util import accuracy as nltk_accuracy
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# nltk.download('movie_reviews')  #Dataset of movie reviews
nltk.download('stopwords') # Common words that usually don't carry much meaning
nltk.download('punkt') # Data for tokenizing (splitting text into words)
nltk.download('subjectivity')
# need to download non-nltk packages, not import
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package subjectivity to /root/nltk_data...
# [nltk_data]   Unzipping corpora/subjectivity.zip.
# True

# %% [markdown]
# ## Exploring the dataset [Task 1]
#
# - Now let's explore the contents and structure of the data set. First I used the help() function.  Doing this, I found I can use other built in functions to to see what categories exist, and look at the first 10 sentences in the dataset.

# %%
# help(nltk.corpus.subjectivity)
# this shows we can use the methods categories() and sents() to explore the data

subjectivity.categories()
# ['obj', 'subj']

# Look at the first 10 sentences:
subjectivity.sents()[:10]

# Create a list of tuples for each category, subjective and objective
subjective_data = [(sentence, 'subj') for sentence in subjectivity.sents(categories='subj')]
objective_data = [(sentence, 'obj') for sentence in subjectivity.sents(categories='obj')]

# Total number of subjective sentences:
print(f"Number of subjective sentences: {len(subjective_data)}")
print(f"Number of objective sentences: {len(objective_data)}")

# Examples of subjective and objective sentences:
print(f"Example subjective sentence: {' '.join(subjective_data[0][0])}")
print(f"Example objective sentence: {' '.join(objective_data[0][0])}")
# Out:
# Number of subjective sentences: 5000
# Number of objective sentences: 5000
# Example subjective sentence: smart and alert , thirteen conversations about one thing is a small gem .
# Example objective sentence: the movie begins in the past where a young boy named sam attempts to save celebi from a hunter .

# %% [markdown]
# ## Feature extraction [Task 2]
#
# - Next, let's create a set of stopwords and define a function to help us remove stopwords from the data set

# %%
stopwords_set = set(stopwords.words('english'))
# Exclude common stopwords to improve the classifier's focus
# print(stopwords_set)

# Implement a feature extraction function that converts sentences into a suitable format for training:
# Create a dictionary containing only non-stopword words
def extract_features(words):
  # Create a dictionary where the keys are words NOT in stopwords set
  return {word: True for word in words if word not in stopwords_set}

# %% [markdown]
# - Prepare to store subjective and objective sentences by initialising lists

# %%
# Initialise two lists (arrays) to hold the subjective and objective snippets
features_subjective = []
features_objective = []

# %% [markdown]
# - Now define a loop to categorise and organise subjective sentences

# %%
for f in subjectivity.fileids('subj'):
  #Extract words
  words = subjectivity.words(fileids=[f])
  #Add the feature to the subjective list with a label
  features_subjective.append((extract_features(words),'Subjective'))

  # look at the data to check it is as expected (my own habit):
  print(features_subjective[:10])
# Out:
# [({'smart': True, 'alert': True, ',': True, 'thirteen': True, 'conversations': True, 'one': True, 'thing': True, 'small': True, 'gem': True, '.': True, 'color': True, 'musical': True, 'bounce': True, 'warm': True, 'seas': True, 'lapping': True, 'island': True, 'shores': True, 'enough': True, 'science': True, 'send': True, 'home': True, 'thinking': True, 'mass-market': True, 'entertainment': True, 'uncompromising': True, 'attempt': True, 'artist': True, 'think': True, 'another': True, 'light-hearted': True, 'french': True, 'film': True, 'spiritual': True, 'quest': True, 'fashion': True, 'model': True, 'seeking': True, 'peace': True, 'mind': True, 'love': True, 'affair': True, 'veterinarian': True, 'non-practicing': True, 'jew': True, 'wife': True, 'actress': True, 'moments': True, 'looking': True, 'comic': True, 'effects': True, 'jealousy': True, 'end': True, 'though': True, 'mildly': True, 'amusing': True, 'could': True, 'much': True, 'works': True, 'engaging': True, 'drama': True, 'incisive': True, 'look': True, 'difficulties': True, 'facing': True, 'native': True, 'americans': True, 'even': True, 'hardened': True, 'voyeur': True, 'would': True, 'require': True, 'patience': True, 'job': True, 'get': True, 'interminable': True, 'shapeless': True, 'documentary': True, 'swinging': True, 'subculture': True, 'perry': True, 'fists': True, 'bull': True, 'moore': True, 'farm': True, 'matter': True, 'time': True, 'gets': True, 'upper': True, 'hand': True, 'matters': True, 'heart': True, 'characters': True, 'paper-thin': True, 'personalities': True, 'undergo': True, 'radical': True, 'changes': True, 'suits': True, 'script': True, 'tired': True, 'joy': True, 'rising': True, 'stale': True, 'material': True, 'bland': True, 'outweighs': True, 'nifty': True, 'cletis': True, 'tout': True, 'never': True, 'becomes': True, 'clever': True, 'crime': True, 'comedy': True, 'thinks': True, 'directed': True, 'david': True, 'twohy': True, 'great': True, 'eye': True, 'eerie': True, 'understatement': True, 'brought': True, 'pitch': True, 'black': True, 'tasteful': True, 'rock': True, 'roll': True, 'movie': True, 'put': True, 'coffee': True, 'table': True, 'anywhere': True, 'provides': True, 'kind': True, "'laugh": True, "therapy'": True, 'need': True, 'comedies': True, '--': True, 'offbeat': True, 'humor': True, 'happy': True, 'ending': True, 'seeing': True, "'analyze": True, "'": True, 'feel': True, 'better': True, 'already': True, 'worth': True, 'sides': True, 'issues': True, 'perspective': True, 'offers': True, 'public': True, 'rarely': True, 'sees': True, 'watching': True, 'like': True, 'reading': True, 'times': True, 'portrait': True, 'grief': True, 'keeps': True, 'shifting': True, 'focus': True, 'journalist': True, 'wrote': True, 'despite': True, 'annoyances': True, 'capable': True, 'clayburgh': True, 'tambor': True, 'really': True, 'anchoring': True, 'emotional': True, 'realities': True, 'middle': True, 'age': True, 'good': True, 'woolly': True, 'mammoths': True, 'extinct': True, 'every': True, 'kid': True, 'schoolyard': True, 'wishing': True, 'preposterous': True, 'tedious': True, 'sonny': True, 'spiked': True, 'unintentional': True, 'laughter': True, 'unfortunately': True, 'occurs': True, 'infrequently': True, 'make': True, 'guilty': True, 'pleasure': True, '4ever': True, 'sledgehammer': True, 'appeal': True, 'pokemon': True, 'videos': True, 'breathes': True, 'big': True, 'screen': True, 'induces': True, 'headaches': True, 'slowly': True, 'si': True, 'el': True, 'siglo': True, 'xxi': True, 'necesita': True, 'de': True, 'hÃ©roes': True, 'hombre': True, 'araÃ±a': True, 'parece': True, 'haber': True, 'llegado': True, 'para': True, 'quedarse': True, 'hard': True, 'tell': True, 'crashing': True, 'banging': True, 'salesmanship': True, 'ends': True, 'begins': True, 'desperately': True, 'wants': True, 'wacky': True, 'screwball': True, 'screwy': True, 'many': True, 'talented': True, 'people': True, 'convinced': True, 'waste': True, 'writer/director': Tr ...

# %% [markdown]
# - Repeat this process to categorise and organise objective sentences

# %%
for f in subjectivity.fileids('obj'):
  #Extract words from the review
  words = subjectivity.words(fileids=[f])
  #Add the feature to the subjective list with a label
  features_objective.append((extract_features(words),'Objective'))

  # look at the data to check it is as expected (my own habit):
  print(features_objective[:10])
# Out:
# [({'movie': True, 'begins': True, 'past': True, 'young': True, 'boy': True, 'named': True, 'sam': True, 'attempts': True, 'save': True, 'celebi': True, 'hunter': True, '.': True, 'emerging': True, 'human': True, 'psyche': True, 'showing': True, 'characteristics': True, 'abstract': True, 'expressionism': True, ',': True, 'minimalism': True, 'russian': True, 'constructivism': True, 'graffiti': True, 'removal': True, 'secured': True, 'place': True, 'history': True, 'modern': True, 'art': True, 'created': True, 'artists': True, 'unconscious': True, 'artistic': True, 'achievements': True, 'spurning': True, "mother's": True, 'insistence': True, 'get': True, 'life': True, 'mary': True, 'thrown': True, 'house': True, 'rejected': True, 'joe': True, 'expelled': True, 'school': True, 'grows': True, 'larger': True, 'child': True, 'amitabh': True, "can't": True, 'believe': True, 'board': True, 'directors': True, 'mind': True, 'filled': True, 'revenge': True, 'better': True, 'robbing': True, 'bank': True, 'ironic': True, 'may': True, 'sound': True, 'among': True, 'others': True, 'excentricities': True, 'talks': True, 'small': True, 'rock': True, 'gertrude': True, 'like': True, 'alive': True, 'gives': True, 'girls': True, 'fair': True, 'chance': True, 'pulling': True, 'wool': True, 'eyes': True, 'using': True, 'sexiness': True, 'poach': True, 'last': True, 'vestige': True, 'common': True, 'sense': True, 'dons': True, 'might': True, 'styled': True, "vh1's": True, '"': True, 'behind': True, 'music': True, 'mockumentary': True, 'profiles': True, 'rise': True, 'fall': True, 'internet': True, 'startup': True, 'called': True, 'icevan': True, 'com': True, 'blue': True, 'predicament': True, ';': True, 'also': True, 'lacks': True, 'ability': True, 'outwardly': True, 'express': True, 'emotions': True, "killer's": True, 'clues': True, 'perversion': True, 'biblical': True, 'punishments': True, 'sins': True, ':': True, 'stoning': True, 'burning': True, 'decapitation': True, 'david': True, 'painter': True, "painter's": True, 'block': True, 'takes': True, 'job': True, 'waiter': True, 'inspiration': True, 'women': True, 'craved': True, 'men': True, 'wanted': True, 'set': True, 'island': True, 'coast': True, 'florida': True, 'techno': True, 'rave': True, 'party': True, 'attracts': True, 'diverse': True, 'group': True, 'college': True, 'coeds': True, 'guard': True, 'officer': True, 'lesson': True, 'learned': True, 'never': True, 'mess': True, 'gay': True, 'mafia': True, '!': True, 'theme': True, 'film': True, 'simultaneously': True, 'addresses': True, 'similarities': True, 'two': True, 'factions': True, 'law': True, 'crime': True, 'revealing': True, 'brothers': True, "they're": True, 'jewish': True, 'grandmothers': True, 'lesbians': True, "he's": True, 'neglecting': True, 'work': True, 'carping': True, 'mom': True, 'behaving': True, 'badly': True, 'toward': True, 'loyal': True, 'friend': True, 'bobbi': True, 'going': True, "gerry's": True, 'estranged': True, 'wife': True, 'margaret': True, 'worried': True, "daughter's": True, 'safety': True, 'finds': True, 'another': True, 'target': True, 'race': True, 'find': True, 'code': True, 'valento': True, 'feels': True, 'heat': True, 'turns': True, 'table': True, 'makes': True, 'dupe': True, 'one': True, 'rubs': True, "da's": True, 'nose': True, 'saigon': True, '1952': True, 'beautiful': True, 'exotic': True, 'mysterious': True, 'city': True, 'caught': True, 'grips': True, 'vietnamese': True, 'war': True, 'liberation': True, 'french': True, 'colonial': True, 'powers': True, 'deep': True, 'northwest': True, 'lone': True, 'ranch': True, 'tucked': True, 'away': True, 'purposefully': True, 'way': True, 'looking': True, 'teenager': True, 'father': True, "there's": True, 'silver': True, 'lead': True, 'says': True, 'rikki': True, 'ortega': True, 'moves': True, 'king': True, 'street': True, '&#193': True, 'nglio': True, 'l': True, "'s": True, 'east': True, 'side': True, 'games': True, 'chasing': True, 'rejecting': True, 'sedu ...

# %% [markdown]
# ## Separate training & testing data [Task 3]

# %% [markdown]
# - First establish the split point to divide the data

# %%
#Split the data into training and testing set (80% training, 20% testing)
threshold_factor = 0.80
threshold_subjective = int(threshold_factor * len(features_subjective))
threshold_objective = int(threshold_factor * len(features_objective))

# %%
#Split the data
#The training set includes the first threshold_subjective features from subjective data and the first threshold_objective features from objective data.
#The testing set includes the remaining features from both subjective and objective data.
features_train = features_subjective[:threshold_subjective] + features_objective[:threshold_objective]
features_test = features_subjective[threshold_subjective:] + features_objective[threshold_objective:]

# %% [markdown]
# ## Time to begin the training

# %%
# Train a Naive Bayes classifier using the training data
classifier = NaiveBayesClassifier.train(features_train)

# Evaluate and print the accuracy of the classifier on the test data
print(f'Accuracy: {nltk_accuracy(classifier, features_test):.2f}')
#gives an accuracy of 1.00, but must consider if there are any false positives if further using the data
# Out:
# Accuracy: 1.00

# %%
#Show which features (words) are most informative in determing the sentiment of a review
most_informative = classifier.most_informative_features()

for feature, weight in most_informative:
    print(f'{feature}: {weight}')
# Out:
# #: None
# #1: None
# #626: None
# #9: True
# $10: None
# $100: None
# $15m: None
# $20: None
# $200: None
# $25: None
# $30: None
# $300: None
# $40: None
# $5: None
# $50-million: None
# $65: None
# $7: True
# $8: True
# $9: True
# %20john: None
# %20laurie: None
# &: True
# &#171: None
# &#173: None
# &#193: None
# &#227: None
# &#237: None
# &#38: None
# '20: True
# '50s: True
# '90s: True
# '[sex: True
# '[the: True
# 'a': None
# 'accident': None
# 'alabama': True
# 'alaipayuthe': None
# 'all: True
# 'alternate: True
# 'amateur': True
# 'an: True
# 'analyze: True
# 'anime': None
# 'anthony: True
# 'arroz: None
# 'artistically': True
# 'artÃ­stico': True
# 'atlantis: True
# 'bad: None
# 'bartleby': True
# 'been: True
# 'belgium's: True
# 'best: True
# 'big: None
# 'blade: True
# 'blonde: None
# 'bloody: None
# 'blue: True
# 'bold': True
# 'boys': None
# 'brass: None
# 'brazil: True
# 'broadway': None
# 'businessman': None
# 'butterfingered': True
# 'buy': None
# 'casting: None
# 'catch: True
# 'challenging': True
# 'chan: True
# 'characters: True
# 'chick: True
# 'chris: True
# 'christian: True
# 'comedy': True
# 'cq: True
# 'cultural: True
# 'date: True
# 'de: True
# 'deadly: True
# 'deliverance': None
# 'deviant': None
# 'difficult': True
# 'dimension: None
# 'direct-to-video': True
# 'divertida: True
# 'do: True
# 'dragon': True
# 'dragonfly': True
# 'drama: True
# 'dramedy': True
# 'drip': None
# 'drumline': True
# 'earn': None
# 'easier': True
# 'edgy: True
# 'ejemplo: True
# 'em: True
# 'enigma': True
# 'enough': True
